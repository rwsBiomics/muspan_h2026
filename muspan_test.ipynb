# %% [markdown]
# # Test of MuSpan
#
# For the full list of tutorials please for version 1.2 see:
#
# - https://docs.muspan.co.uk/v1.2.0/tutorials.html

# %%
# Check MuSpan is installed in then python environment.
import muspan
print("All good.")
# Out:
# All good.
